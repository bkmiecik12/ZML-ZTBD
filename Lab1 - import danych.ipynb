# %%
import os
import pandas as pd

main_table = pd.read_csv('data//eth_v_d.csv', index_col='Data')

files=os.listdir('data/')
files.remove('eth_v_d.csv')

for file in files:
  print(file+'\n');
  right = pd.read_csv('data/'+file, index_col='Data', engine='python')
  main_table = main_table.merge(right=right, 
                                how = 'inner', 
                                left_index=True, 
                                right_index=True, 
                                copy=False, 
                                suffixes=('','_'+file[:-4]))
  
main_table.to_csv('data/results')
main_table.head()
# Out:
# bch_v_d.csv
#
# bnb_v_d.csv
#
# btc_v_d (1).csv
#
# comp_v_d.csv
#
# eurchf_d.csv
#
# eurpln_d.csv
#
# eurusd_d.csv
#
# fw20_d.csv
#
# mkr_v_d.csv
#
# results.csv
#
# usdchf_d.csv
#
# usdeur_d.csv
#
# usdpln_d.csv
#
# wig20_d.csv
#
# wig_d.csv
#             Otwarcie  Najwyzszy  Najnizszy  Zamkniecie  Otwarcie_bch_v_d  \
# Data
# 2020-06-19    229.89     232.42     226.61      229.56            235.08
# 2020-06-22    229.42     246.74     227.09      243.12            232.08
# 2020-06-23    243.07     244.84     240.89      244.16            242.30
# 2020-06-24    244.16     249.12     231.10      234.60            242.20
# 2020-06-25    234.61     235.58     227.46      234.09            232.40
#
#             Najwyzszy_bch_v_d  Najnizszy_bch_v_d  Zamkniecie_bch_v_d  \
# Data
# 2020-06-19             236.62             230.41              233.97
# 2020-06-22             243.86             229.69              242.33
# 2020-06-23             244.21             239.37              242.20
# 2020-06-24             245.35             229.66              232.39
# 2020-06-25             234.71             226.36              233.07
#
#             Otwarcie_bnb_v_d  Najwyzszy_bnb_v_d  ...  Otwarcie_wig20_d  \
# Data                                             ...
# 2020-06-19             16.07              16.27  ...           1791.68
# 2020-06-22             15.99              16.58  ...           1805.25
# 2020-06-23             16.42              16.57  ...           1807.10
# 2020-06-24             16.41              16.66  ...           1830.39
# 2020-06-25             16.05              16.18  ...           1781.84
#
#             Najwyzszy_wig20_d  Najnizszy_wig20_d  Zamkniecie_wig20_d  \
# Data
# 2020-06-19            1809.23            1791.68             1807.85
# 2020-06-22            1807.19            1786.99             1797.05
# 2020-06-23            1847.33            1806.21             1825.99
# 2020-06-24            1836.89            1784.23             1784.23
# 2020-06-25            1798.80            1759.21             1793.36
#
#             Wolumen_wig20_d  Otwarcie_wig_d  Najwyzszy_wig_d  Najnizszy_wig_d  \
# Data
# 2020-06-19         91765353        50501.03         50676.93         50458.76
# 2020-06-22         43852662        50642.94         50815.34         50300.67
# 2020-06-23         44376322        50942.90         51863.82         50841.55
# 2020-06-24         38481948        51616.42         51694.81         50478.37
# 2020-06-25         33804564        50346.03         50767.04         49870.68
#
#             Zamkniecie_wig_d  Wolumen_wig_d
# Data
# 2020-06-19          50670.08    118188907.0
# 2020-06-22          50606.02     87416733.0
# 2020-06-23          51438.30    102495651.0
# 2020-06-24          50479.64     84756272.0
# 2020-06-25          50658.89     69576460.0
#
# [5 rows x 196 columns]
